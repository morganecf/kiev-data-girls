# %%
'''Notebook to demonstrate basic feature extraction steps'''
# Out:
# 'Notebook to demonstrate basic feature extraction steps'

# %%
# We saw during EDA how to find the top words related to sentiment
# But how can we turn these into features that can be used to train
# a model?

# %%
import pandas as pd

# Read in data. Use latin-1 encoding (single-byte encoding scheme).
# utf-8 is multi-byte encoding scheme.
df = pd.read_csv('sample_tweets.csv', encoding='latin-1')

# %%
# Some basic cleaning: lower, remove stopwords, remove hashtags, mentions, urls

## TODO: don't remove hashtags
## TODO: maybe look at hashtags in EDA

# Lower and remove stopwords
from stop_words import get_stop_words
stop_words = set(get_stop_words('en'))
df.text = df.text.str.lower().str.split().apply(lambda words: ' '.join([w for w in words if w not in stop_words]))

# %%
df.text.head(10)
# Out:
# 0    @switchfoot http://twitpic.com/2y1zl - awww, b...
# 1    upset update facebook texting it... might cry ...
# 2    @kenichan dived many times ball. managed save ...
# 3                     whole body feels itchy like fire
# 4    @nationwideclass no, behaving all. mad. here? ...
# 5                                 @kwesidei whole crew
# 6                                             need hug
# 7    @loltrish hey long time see! yes.. rains bit ,...
# 8                                      @tatiana_k nope
# 9                                @twittera que muera ?
# Name: text, dtype: object

# %%
# Remove hashtags, mentions, urls
## TODO don't remove hashtags
mention = r'^(.*\s)?@\w+'
hashtag = r'^(.*\s)?#\w+'
url = r'^((http[s]?|ftp):\/)?\/?([^:\/\s]+)((\/\w+)*\/)([\w\-\.]+[^#?\s]+)(.*)?(#[\w\-]+)?$'
df.text = df.text.str.replace(mention, '').str.replace(hashtag, '').str.replace(url, '')

# %%
# TODO: url not working?
df.text.head(10)
# Out:
# 0     http://twitpic.com/2y1zl - awww, bummer. shou...
# 1    upset update facebook texting it... might cry ...
# 2     dived many times ball. managed save 50% rest ...
# 3                     whole body feels itchy like fire
# 4              no, behaving all. mad. here? see there.
# 5                                           whole crew
# 6                                             need hug
# 7     hey long time see! yes.. rains bit ,only bit ...
# 8                                                 nope
# 9                                          que muera ?
# Name: text, dtype: object

# %%
# We obviously want to use words as features. But what might be
# more information is using SEQUENCE of words. These are called
# n-grams. For example:

s = 'I have studied many philosophers and many cats. The wisdom of cats is infinitely superior.'

# Show complete list in presentation
unigram = ['studied', 'many', 'philosophers', 'and', 'many', 'cats']
bigrams = ['many philosophers', 'many cats', 'wisdom of', 'infinitely superior']
trigrams = ['I have studied', 'studied many philosophers', 'wisdom of cats', 'is infinitely superior']

# As n increases, the more informative the string of words becomes
# But as n increases, the less common the sequence becomes
# We want to find n > 1 that still captures information

# %%
# Use scikit-learn's CountVectorizer to find n-gram counts
from sklearn.feature_extraction.text import CountVectorizer

# %%
# Initialize word vectorizer: we'll find n-grams with n == 1, 2, 3 
word_vectorizer = CountVectorizer(ngram_range=(1, 3), analyzer='word')
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 3), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
## Illustrate vocabulary and so on
word_vectorizer.fit_transform([s]).vocabulary_

# %%
# We don't have to do some of the preprocessing from earlier - can use options here
# Lowercased by default. Can also pass in a preprocessor to address our domain-specific
# cleaning.
def preprocess(word):
    return word.replace(mention, '').replace(url, '')
    
word_vectorizer = CountVectorizer(ngram_range=(1, 3), analyzer='word', preprocessor=preprocess, stop_words=stop_words)
word_vectorizer
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 3),
#         preprocessor=<function preprocess at 0x104516f28>,
#         stop_words={'all', 'until', "we'd", "we've", 'the', 'above', 'be', 'most', "when's", "where's", 'yourselves', 'very', 'when', 'its', "hadn't", 'for', 'have', 'on', 'was', 'each', 'would', "shan't", "there's", "didn't", "won't", 'itself', 'he', 'own', 'but', 'i', 'am', 'too', 'an', 'her', 'those', "w...th', "shouldn't", "let's", "weren't", "can't", 'so', 'or', 'myself', 'same', "haven't", 'is', 'any'},
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
# Isolate text and target
target = df.polarity
tweets = df.text

# %%
# Create word by document matrix
word_doc_matrix = word_vectorizer.fit_transform(tweets)

# rows: documents (tweets)
# columns: words -- all words across ALL tweets
# entry i, j: number of times word(j) occurs in document(i)
word_doc_matrix
# Out:
# <9999x116252 sparse matrix of type '<class 'numpy.int64'>'
# 	with 181840 stored elements in Compressed Sparse Row format>

# %%
# View the learned vocabulary of n-grams
word_vectorizer.vocabulary_
# Out:
# {'renting cheap': 82183,
#  'well tired': 110232,
#  'watched tv time': 108790,
#  'melbourne': 62936,
#  'tomorrow drinking coffee': 101441,
#  'new student short': 68476,
#  'exams killed': 29774,
#  'nights rest': 69358,
#  'lipstick': 56990,
#  'bio hello kills': 11150,
#  'birthday finished': 11239,
#  'gonna start twittering': 39491,
#  'now 199': 69953,
#  'girl options none': 37454,
#  'cant commit': 15556,
#  'dead now': 23453,
#  'bad spills tuesday': 9063,
#  'probably cranky': 78117,
#  'revisions feel': 82726,
#  'today ready weekend': 101052,
#  'nah people': 67009,
#  'eating ana candy': 27271,
#  'javelins though': 50437,
#  'missing bff': 64463,
#  '40 mins blew': 1362,
#  'wolmyeong getting ready': 112167,
#  'right thing': 83043,
#  'quot came': 79383,
#  'employ': 28012,
#  'prayer': 77604,
#  'tak faham': 95942,
#  'better rec': 10802,
#  'use different': 106045,
#  'wonderful conversation thnx': 112258,
#  'gosh made': 40351,
#  'crying inside please': 21498,
#  'better normal mode': 10776,
#  'feel sick much': 31591,
#  'freaking right now': 34459,
#  'filled application case': 32175,
#  'promised leave right': 78504,
#  '07am': 83,
#  're daily': 80531,
#  'im afraid ur': 48389,
#  'sad killed': 84097,
#  'avalon': 7452,
#  'think going home': 98508,
#  'listening telepopmusik sooooo': 57163,
#  'got done': 40526,
#  'find way just': 32580,
#  'user thier': 106204,
#  'track studio lost': 102381,
#  'system finally gave': 95815,
#  'wordpress much': 112535,
#  'yupp haha need': 115980,
#  'scene will': 85106,
#  'wish understood': 111808,
#  'almost falling stairs': 3909,
#  'thanks great show': 97655,
#  'simple hope find': 88454,
#  'location now can': 57724,
#  'last night went': 54412,
#  'keeeerrrrriiiiii really nothing': 52488,
#  'stalkdaily': 92350,
#  'someone ratsofatsorat left': 90431,
#  'feat snoop dog': 31325,
#  'idea overdoing': 48091,
#  'screen shot': 85495,
#  'kitty eva': 53186,
#  'day fishing': 22787,
#  'forward day': 34116,
#  'barely watching': 9482,
#  'right noww': 83007,
#  'facebook publishing annoy': 30471,
#  'crashed hand': 21092,
#  'seobook com worthless': 86669,
#  'work without ninja': 113098,
#  'stuart': 94005,
#  'hungry trying': 47750,
#  'fucking phone': 35202,
#  'sad heart': 84076,
#  'blasty': 11679,
#  'losing follower probably': 58815,
#  'give 4gb memory': 37545,
#  'day offffff': 23006,
#  'laury': 54842,
#  'bad sure': 9068,
#  'know going cool': 53446,
#  'wanna see spencer': 107935,
#  'hours see': 47076,
#  'someone pulling leg': 90425,
#  'foot morning jumping': 33836,
#  'getty': 37287,
#  'live life expectancy': 57400,
#  'dutch dark': 26731,
#  'fun eat': 35326,
#  'dishing quot': 24927,
#  'made bill': 60627,
#  'careful luisa': 15911,
#  'go afternoon watch': 37929,
#  'hate sappy kind': 43711,
#  'mother fucker': 65703,
#  'hi just': 45203,
#  'internets': 49646,
#  'im awake people': 48403,
#  'weight summer': 109841,
#  'phrases': 75461,
#  'dunk': 26669,
#  'basically': 9540,
#  'pn mau jln': 76790,
#  'upload work': 105645,
#  'new phone got': 68405,
#  'com 798k1 looks': 18730,
#  'filmmakers great alround': 32223,
#  'standard wherever go': 92378,
#  'planned going': 76146,
#  'tired tired': 100495,
#  'fave n64': 31165,
#  '5am': 1596,
#  'server': 86788,
#  'thing learnt sinusitis': 98173,
#  'lips ass': 56985,
#  'anything like': 5866,
#  'haha hope': 42553,
#  'worry good can': 113607,
#  'financial': 32418,
#  'wish sydney': 111797,
#  'fr amp sprint': 34349,
#  'work snowing': 112982,
#  'mibbit': 63289,
#  'summer hot': 94747,
#  'herpes different': 44941,
#  'slow internet': 89672,
#  'agar will': 3118,
#  'anyway thought': 5947,
#  'watching one tree': 108926,
#  'interesting haha': 49525,
#  'com blogs': 18798,
#  'really like': 81222,
#  'ready piss': 80857,
#  'every job': 29301,
#  'day still going': 23116,
#  'smithsonian': 89903,
#  'lucky son gun': 60139,
#  'shed tears shhh': 87221,
#  'just said baby': 52026,
#  'day government': 22838,
#  'ok always get': 71604,
#  'spain move around': 91660,
#  'christiania': 17532,
#  'sunshine tequila': 95013,
#  'strictest official': 93913,
#  'come ur': 19149,
#  'like run speakeasy': 56483,
#  'wonders someone': 112355,
#  'gh promenade just': 37301,
#  'tour quot': 102231,
#  'saying bye': 84943,
#  'worst possible moments': 113680,
#  'early awake zzz': 26910,
#  'longer playing': 58335,
#  'oh still take': 71434,
#  'spent hour': 91930,
#  'mile': 63604,
#  'let gys': 55616,
#  'romania minipig': 83401,
#  'welcome every day': 109896,
#  'sweets first time': 95642,
#  'message haha head': 63135,
#  'hq': 47290,
#  'luggage fucking': 60151,
#  'report card': 82297,
#  'saw ice rain': 84738,
#  'haha cried guess': 42514,
#  'feel hot': 31502,
#  'light headed': 56001,
#  'lt lt lt': 59943,
#  'new sites want': 68460,
#  'today prokofiev': 101041,
#  'favourite character': 31228,
#  'recording': 81652,
#  'lappy touch pad': 54170,
#  'fight': 32074,
#  'hear love little': 44251,
#  'hope things will': 46511,
#  'actually work time': 2693,
#  'hate sick': 43720,
#  'await': 7533,
#  'unburnable calories': 105098,
#  'users mines done': 106219,
#  'daily coffee dosage': 22112,
#  'graphic instead music': 41217,
#  'house well done': 47213,
#  'come far': 19040,
#  '½also': 116137,
#  '7j66t': 1834,
#  'idea im': 48077,
#  'today hopefully takes': 100891,
#  'baby huntsman': 8292,
#  '40 degress today': 1358,
#  'ha ha': 42372,
#  'usually fitted makes': 106321,
#  'baseball': 9516,
#  'resent always struck': 82401,
#  'wondering much': 112328,
#  'love time year': 59575,
#  'famï ½es': 30806,
#  'insights community just': 49333,
#  'couldnt fit': 20635,
#  'laws coming easter': 54869,
#  'much wish 45pm': 66429,
#  'ilpc oh ps': 48370,
#  'lmao feel someone': 57575,
#  'crayon box red': 21121,
#  'responded': 82442,
#  'levy': 55770,
#  'charger': 16797,
#  'just sleep': 52088,
#  'lhao': 55786,
#  'time super bored': 100090,
#  'back curtains': 8461,
#  'http news': 47412,
#  'man thanks': 61516,
#  'threatening': 99258,
#  'kill test': 52940,
#  'several': 86937,
#  'updates plurk': 105568,
#  'gt biofuel proposal': 41839,
#  'gig famous': 37348,
#  'just take': 52145,
#  'missed cut': 64318,
#  'blues away': 12101,
#  'guilty even': 42026,
#  'total drama island': 102062,
#  'got rest': 40793,
#  'behind': 10263,
#  'talking write paper': 96381,
#  'engineering': 28194,
#  'qa backend discovered': 79056,
#  'news finally': 68590,
#  'chai latte': 16518,
#  'im spain': 48690,
#  'last message didnt': 54333,
#  'sumtimes': 94812,
#  'see new star': 86004,
#  'schedule allows go': 85119,
#  'facebooked twittered birthday': 30492,
#  'hmm cari aja': 45544,
#  'odd religion course': 70983,
#  'nothing today probably': 69892,
#  'thursday': 99446,
#  'even google translator': 29009,
#  'accessed oneindia mobi': 2375,
#  'thank wonderfully magical': 97499,
#  'change background color': 16613,
#  'night creaks': 69090,
#  'thanks amp good': 97543,
#  'near work': 67346,
#  'catch talking': 16159,
#  'official hooters interview': 71114,
#  'tantan': 96432,
#  'shoes lt': 87524,
#  'new town': 68494,
#  'ad': 2706,
#  'another story': 5575,
#  'unless little cricket': 105394,
#  'workout': 113347,
#  'process': 78266,
#  'frogs becoming': 35016,
#  'massive headache building': 62016,
#  'home today catching': 46000,
#  'luck greece': 60025,
#  'understated wish cud': 105196,
#  'list things': 57035,
#  'cleaning much appreciated': 17884,
#  'disc event excited': 24836,
#  'shame mutt': 87095,
#  'quot tons': 79944,
#  'target get lvatt': 96491,
#  'now chunky': 70044,
#  'believed lucky': 10364,
#  'til end wk': 99647,
#  'scream quot parody': 85475,
#  'next week feedback': 68736,
#  'much brains fried': 66165,
#  'slept wink severe': 89584,
#  'stuck traffic': 94061,
#  'measles': 62703,
#  'love cute': 59201,
#  'hope goes away': 46364,
#  'good ben jerrys': 39566,
#  'download disappointed going': 25909,
#  'flaws scars': 33232,
#  'non stop hihi': 69605,
#  'concert miami next': 19728,
#  'kashi chicken spinach': 52435,
#  'cash toothbrush passport': 16053,
#  'please say': 76557,
#  'laughed': 54765,
#  'section': 85767,
#  'ever told never': 29262,
#  'luggage': 60148,
#  'file server home': 32144,
#  'glass dublin': 37799,
#  'lack quot tweets': 53990,
#  'broken screen': 13576,
#  'cuddle make ass': 21573,
#  'healthy dining': 44172,
#  'book though': 12357,
#  'rapidly': 80391,
#  'boring can tell': 12599,
#  'feral children wise': 31958,
#  'homesick criminals breakn': 46069,
#  'home chocolate': 45825,
#  'brother know stop': 13621,
#  'said ok': 84377,
#  'back bangkok': 8400,
#  'free stuff http': 34542,
#  'death toll': 23587,
#  'go dinner owe': 38074,
#  'ive pretty': 50214,
#  'write stack pointer': 113922,
#  'btw eventbox available': 13796,
#  'keri hilson': 52707,
#  'st win': 92291,
#  'air today worries': 3554,
#  'tinyurl com ceprvs': 100325,
#  'awake lots': 7577,
#  'illness type': 48360,
#  'thing listen morning': 98179,
#  'chennai': 17159,
#  'time look yet': 99970,
#  'tyler now': 104697,
#  'way recent': 109208,
#  'settled': 86924,
#  'goodmorning goodmorning': 40174,
#  'lodge never made': 57738,
#  'assignmenting gay sick': 7065,
#  'eat cheaply man': 27203,
#  'around fun ask': 6587,
#  'help can get': 44767,
#  'happened accidently': 43179,
#  'later quot': 54688,
#  'hear will highlight': 44311,
#  'home girlfriend baby': 45863,
#  'friends search tweets': 34940,
#  '33gb': 1217,
#  'away today grr': 7735,
#  'easy shift': 27187,
#  'set thingy place': 86889,
#  'ah ha': 3307,
#  'trawl': 102643,
#  'finally changed': 32284,
#  'groups': 41754,
#  'hello tuesday': 44732,
#  'smiling foreigner': 89891,
#  'one letter alway': 72406,
#  'morning twitterland': 65597,
#  '64 http bit': 1674,
#  'even stand fml': 29085,
#  'comes tomorrow': 19204,
#  'wish best exam': 111625,
#  'sf trip': 87005,
#  'quot jeremy': 79599,
#  'got streetcar essay': 40854,
#  'parish really': 74115,
#  'going look houses': 38964,
#  'thx everyone': 99497,
#  'roach carry go': 83181,
#  'alike diferent quot': 3796,
#  'still pounding friday': 93248,
#  'xbox ages': 114298,
#  '10 ve happily': 164,
#  'now miss meg': 70301,
#  'telecom works wifi': 96906,
#  'earbuds sennheiser': 26869,
#  'struggling': 93983,
#  'day good shopping': 22832,
#  'finally class': 32288,
#  'delayed problems finished': 23879,
#  'yes please': 115339,
#  '3pm use lapt': 1327,
#  'ugghh bored': 104794,
#  'finally home sooo': 32344,
#  'burnt youch': 14158,
#  'one lovely': 72423,
#  'psyched many': 78691,
#  'zumba yoga kicked': 116084,
#  'love indeed': 59320,
#  'still go socal': 93107,
#  'renting awesome': 82181,
#  'james joyce': 50351,
#  'dallas thumbsup though': 22148,
#  'just watched happens': 52282,
#  'amp reviewed': 4989,
#  'try gmat': 103117,
#  'quot rotation': 79830,
#  'shoulda got': 87732,
#  'bust 2day': 14246,
#  'replace': 82222,
#  'replies may': 82260,
#  'writes word auch': 113950,
#  'windows suspected hope': 111507,
#  'well know': 110082,
#  'know one person': 53581,
#  'sacrifice will': 84024,
#  'sorry maybe walking': 91294,
#  'one died morning': 72255,
#  'cheering': 17088,
#  'trying times': 103289,
#  'ahhhhh leaving will': 3457,
#  'voted lead': 107188,
#  'lol better': 57797,
#  'awwwww memories': 8126,
#  'angel gettin': 5248,
#  'let mcgee hahahaha': 55637,
#  'well hard': 110044,
#  'will great wait': 111077,
#  'gym mp3': 42318,
#  'internet runs': 49626,
#  'excited hubby bday': 29916,
#  'class time': 17799,
#  'zrovna': 116076,
#  'working holy week': 113228,
#  'gone bed': 39292,
#  'cousin twitter': 20869,
#  'blip fm 8bfg6': 11793,
#  'telll gay': 97033,
#  'going http': 38908,
#  'throughout 2008 never': 99352,
#  'yawwwnn tired love': 114584,
#  '½n': 116170,
#  'kitten female': 53175,
#  'tribunal tomorrow try': 102752,
#  'ahh ive always': 3406,
#  'ads': 2885,
#  'chronic ones assume': 17560,
#  'namaste': 67055,
#  'working doubt': 113201,
#  'lt real ninnies': 59968,
#  'epcot': 28554,
#  'nawww love dont': 67293,
#  'papers available': 74031,
#  'hang anyone use': 43083,
#  'blue one pretty': 12085,
#  'people may need': 74834,
#  'make moneys ideas': 61045,
#  'http www pollstar': 47488,
#  'one tweets omb': 72590,
#  'mahavir jayanti contd': 60824,
#  'ton free frozen': 101605,
#  'ednaiscool51 yay videos': 27457,
#  'open course must': 72903,
#  'cause sick stand': 16263,
#  '½s songs child': 116187,
#  'thanks explanation': 97623,
#  'persecute': 75028,
#  'scratches': 85460,
#  'career sites used': 15909,
#  'tried swatching new': 102816,
#  'will got': 111072,
#  'convention': 20135,
#  'xong ng': 114358,
#  'like world': 56672,
#  'snowed today': 90100,
#  'go bad work': 37969,
#  'make nasty': 61057,
#  'blowdried styled now': 12060,
#  'believe last week': 10348,
#  'feckin arseholed': 31364,
#  'company work': 19486,
#  'watching himym': 108876,
#  'fm going back': 33474,
#  'tomorrow realizing now': 101543,
#  'pandas': 73945,
#  'remember 9th': 82065,
#  'live frog market': 57387,
#  'migraine making tummy': 63566,
#  'yeah weekend': 114978,
#  'girl love special': 37444,
#  'now head': 70182,
#  'hangin mmmmiiiikkkkyyyyllllaaaa': 43103,
#  'stir crazy bought': 93435,
#  'results politics': 82565,
#  'nobody can see': 69504,
#  'tweets go hit': 103928,
#  'go back bed': 37950,
#  'area familiar': 6414,
#  'happy doc': 43319,
#  'back work': 8807,
#  'without saying': 111956,
#  'time just think': 99946,
#  'letters sent': 55713,
#  'engineer': 28192,
#  'sunshine bad work': 95002,
#  'red onion': 81710,
#  'england though': 28207,
#  'dollar': 25403,
#  'isnt lookin': 50024,
#  'naps': 67180,
#  'hoping sit': 46658,
#  'lin meijiao entertaining': 56839,
#  'today can': 100706,
#  'dyed roving': 26783,
#  'bring can': 13389,
#  'hurt like': 47824,
#  'run boyfriend': 83814,
#  'ugh really': 104856,
#  'jason': 50423,
#  'dentist twitter': 24032,
#  'blip quot': 11813,
#  'twitter name day': 104343,
#  'le': 54967,
#  'just gotta keep': 51685,
#  'buyology': 14508,
#  'internal corp': 49571,
#  'apologies please fogive': 6016,
#  'theaters long': 98000,
#  'comin columbus oh': 19253,
#  'jersey fam breakfast': 50624,
#  'fualt lets hope': 35114,
#  'apts must done': 6374,
#  'stay tune proper': 92798,
#  'da boss': 22000,
#  'passed last': 74339,
#  'bought sour': 12757,
#  'croissant tuna knowing': 21358,
#  'one bedroom left': 72168,
#  'figure want': 32111,
#  'error check things': 28700,
#  'oh agents booked': 71183,
#  'maintenance quot': 60910,
#  'triop': 102846,
#  'ya ll updated': 114446,
#  'well hope tweet': 110062,
#  'murder someone grrr': 66583,
#  'paper oh wait': 74020,
#  'see leave ll': 85961,
#  'behavior http': 10261,
#  'think going catch': 98506,
#  'beerbq': 10214,
#  'bed dogs heaven': 10035,
#  'always plus bigger': 4395,
#  'now di ko': 70075,
#  'will soon': 111289,
#  'amazingly level': 4579,
#  'ahaha sad pineapple': 3372,
#  'entry level': 28511,
#  'look lovely': 58449,
#  'hsnging friends damn': 47323,
#  'got get': 40589,
#  'just got new': 51664,
#  've': 106504,
#  'ireland luck poxy': 49917,
#  'talking': 96344,
#  'op weeks biopsy': 72894,
#  'find stories make': 32564,
#  'http yfrog': 47508,
#  'need http tumblr': 67558,
#  'atmosphere http tweet': 7203,
#  'one month rather': 72439,
#  'flashes': 33188,
#  'people know now': 74809,
#  'camp overnight': 14960,
#  'jealous going': 50505,
#  'manila': 61632,
#  'news sorry hear': 68618,
#  'want easter break': 108042,
#  'album omg': 3697,
#  'reader': 80698,
#  'amp red carpet': 4979,
#  'cabin campground will': 14586,
#  'morning rainy france': 65500,
#  'twats probably': 103683,
#  'sad topic': 84213,
#  'sina': 88499,
#  'ether sitting mailbox': 28863,
#  'yge worked yesterday': 115705,
#  'early free': 26933,
#  'love onu admissions': 59426,
#  'will sorry': 111292,
#  'around lj': 6607,
#  'really sucked understand': 81370,
#  'time sleep dreaming': 100071,
#  'another week talk': 5590,
#  'watching new house': 108916,
#  'cuz lack': 21907,
#  'button working': 14373,
#  'approach new patterns': 6277,
#  'shindigs thats': 87301,
#  'weekly wow': 109777,
#  'can new': 15256,
#  'thesis thesis': 98078,
#  'found pretty': 34262,
#  'shits dead tired': 87440,
#  'imac came': 48795,
#  'correction tell cert': 20516,
#  'chosen well': 17501,
#  'fuck bring fuck': 35120,
#  'noagenda': 69487,
#  'roomie home': 83480,
#  'gears': 36038,
#  'try get sleep': 103116,
#  'alchy': 3746,
#  'just woke vivid': 52324,
#  'sucks start like': 94549,
#  'panny cams': 73970,
#  'days difficults': 23266,
#  'engr': 28252,
#  'killed eggnog thread': 52952,
#  'gys': 42349,
#  'one cause get': 72199,
#  'andrew suggestion might': 5214,
#  'easily': 27106,
#  'think just eat': 98549,
#  'gb': 35971,
#  'dear fbdimms please': 23530,
#  'safe phone': 84298,
#  'taking short': 96204,
#  'miss super fast': 64264,
#  'view listen': 106887,
#  'groove': 41700,
#  'computers suck big': 19673,
#  'came home': 14891,
#  'milk': 63649,
#  'sure want': 95342,
#  'sound funny': 91452,
#  'fuckkeeddddd': 35214,
#  'roblox telemon': 83240,
#  'applied go dad': 6209,
#  'much never know': 66311,
#  'meanwhile': 62697,
#  'eat set': 27237,
#  'mqu': 65990,
#  'getting old': 37197,
#  'wait waaaaaait': 107456,
#  'morning pulled back': 65490,
#  'stay house': 92783,
#  'foss using': 34187,
#  'wait reviews come': 107416,
#  'keep post': 52576,
#  'conference canceled': 19782,
#  'moving moving moving': 65958,
#  'debbie': 23599,
#  'gen': 36092,
#  'want wish warlock': 108295,
#  'every1': 29350,
#  'rash bum': 80410,
#  'net bloody': 67926,
#  'today well 90': 101186,
#  'fell asleep class': 31868,
#  'moment using': 64848,
#  'true glad': 103008,
#  'tho mostly': 98928,
#  'later boy going': 54652,
#  'im pretty happy': 48631,
#  'crawl': 21116,
#  'journal taken': 51098,
#  'interesting stuff come': 49544,
#  'bid govt': 10930,
#  'saying just': 84954,
#  'codez ve mia': 18318,
#  'jackhammers': 50293,
#  'crime guess': 21314,
#  'rt': 83686,
#  'throat closing': 99316,
#  'comedy': 19166,
#  'sleep glad': 89250,
#  'patio named': 74459,
#  'cheap ask': 16898,
#  'good germany today': 39684,
#  'find like aus': 32492,
#  'yay new': 114654,
#  'ideas hello fathers': 48123,
#  'wish gotta': 111683,
#  'gotta repeat whole': 41027,
#  'got excited learned': 40553,
#  'podcast debate now': 76803,
#  'hehe noon overhere': 44562,
#  'adding': 2799,
#  'tempted get imma': 97070,
#  'thanks thoughts amp': 97824,
#  'used cd lost': 106125,
#  'finger hurts really': 32667,
#  'webinar': 109454,
#  'sucked understand': 94483,
#  'juggle tiki': 51185,
#  'disapptin just woke': 24825,
#  'coz alison': 20928,
#  'training new job': 102530,
#  'shopping opera tomorrow': 87614,
#  'sana realized': 84516,
#  'people get like': 74778,
#  'http apps facebook': 47340,
#  'nap probably wake': 67165,
#  'pas': 74307,
#  'four games fall': 34320,
#  'final assessments assessments': 32245,
#  'tends': 97090,
#  'sipping': 88731,
#  'eyeliner feel': 30325,
#  'want money kevo': 108162,
#  'pose ta': 77191,
#  'brightly': 13344,
#  'tay plz': 96626,
#  'keeping nate amp': 52622,
#  'old vb6': 71936,
#  'back guess': 8525,
#  'doc': 25164,
#  'nother': 69810,
#  'emo want': 27992,
#  'days birthday': 23253,
#  'since hit 340': 88559,
#  'www chargebikes': 114168,
#  'steve': 92924,
#  'instead needs': 49447,
#  'side tan': 88254,
#  'just stay': 52127,
#  'com http bit': 18867,
#  'remains missing northern': 82048,
#  'useful quality': 106179,
#  'everyone feeling better': 29422,
#  'hurts wonder': 47895,
#  'cuz old': 21914,
#  'cordial': 20457,
#  'sooo go see': 90996,
#  'refocused can': 81825,
#  'birding http ff': 11182,
#  'bill just': 11106,
#  'must mean': 66755,
#  'chloroformed': 17390,
#  'world wonderfully will': 113542,
#  'clouds gliding': 18139,
#  '7th': 1881,
#  'find australia': 32436,
#  'ad makes': 2711,
#  'komodo dragon': 53833,
#  'reply directly': 82268,
#  'waaahhh': 107271,
#  'met really': 63209,
#  'great last night': 41375,
#  'can two': 15410,
#  'zipping back': 116039,
#  'never showed always': 68106,
#  'gardner took rip': 35875,
#  'died last january': 24477,
#  'com 2y5uv': 18702,
#  'positive reason made': 77206,
#  'soaked wet couldn': 90136,
#  'frens': 34661,
#  'im leave history': 48575,
#  'almost 700 replies': 3894,
#  'morning fill today': 65344,
#  'feeter': 31859,
#  'reports letterman': 82324,
#  'okay bbs': 71740,
#  'tragedy disaster news': 102451,
#  'thing wont': 98252,
#  'thank entertainment much': 97393,
#  'terrible yesterday': 97170,
#  'thanks hate': 97663,
#  'bloaty headache woman': 11840,
#  'rather give feedback': 80434,
#  '2y7g0': 1060,
#  'bed today': 10132,
#  'crab liten': 20980,
#  'please please can': 76549,
#  'get touch email': 36908,
#  'sudden': 94569,
#  'hate work': 43764,
#  'kicking face': 52815,
#  'ref_name': 81794,
#  'nearing finish line': 67353,
#  'cd car': 16323,
#  'quot love love': 79664,
#  'issue entirely': 50049,
#  'expires': 30144,
#  'award goes': 7620,
#  'guitar lessons': 42038,
#  'put back': 78914,
#  'hinge broke': 45413,
#  'v5 content': 106383,
#  'blasted colds': 11676,
#  'place days help': 76030,
#  'never lose things': 68075,
#  'week thought': 109691,
#  'bit bored': 11337,
#  'jeffrey today tell': 50561,
#  'swine feeling': 95685,
#  'faerie deviantart com': 30559,
#  'xml': 114353,
#  'drunk put tshirt': 26471,
#  'day mutemath': 22974,
#  'yoyoyoy': 115866,
#  'told extremely good': 101314,
#  'exciting day': 29979,
#  'think bo bee': 98435,
#  'latest': 54724,
#  'sixteen yay fun': 88997,
#  'get old hehe': 36684,
#  'debbugging': 23601,
#  'going loooooooooooooooooooooooooooooooonnnnnnngggggggg': 38967,
#  'sucks leave': 94533,
#  'feel bored': 31462,
#  'hiya slides mean': 45528,
#  'hope will caffine': 46532,
#  'apparently 10': 6071,
#  'back spent entire': 8742,
#  'wtfuck': 114119,
#  'screen name': 85494,
#  'everybody else rattling': 29358,
#  'government put pressure': 41081,
#  'muir dr': 66479,
#  'late work still': 54624,
#  'maguire': 60816,
#  'history watching': 45459,
#  'mom': 64743,
#  'damn growing oh': 22217,
#  'messes although': 63175,
#  'glass oj': 37809,
#  'gay sick': 35962,
#  'love guy': 59278,
#  'someones sick lets': 90474,
#  'great show shame': 41458,
#  'lot stress dealing': 58994,
#  'time talk lmfaoo': 100098,
#  'anoop mean': 5428,
#  'twit': 104069,
#  'ichthus year www': 48031,
#  'selena demi': 86415,
#  'poor mel': 77057,
#  'work till 30pm': 113029,
#  'next ap': 68651,
#  'wear short': 109340,
#  'new one': 68390,
#  'hope gain speech': 46345,
#  'toll italy': 101351,
#  'post imagine haveing': 77287,
#  'gotta homework': 40999,
#  'balls although without': 9260,
#  'set thingy': 86888,
#  'cookies forr': 20205,
#  'last 02 process': 54265,
#  'pix soon': 75981,
#  'like scene straight': 56500,
#  'way downhill': 109094,
#  'varicose veins dad': 106488,
#  'thru cooking': 99386,
#  'really want see': 81413,
#  'work ve': 113076,
#  'fork enjoyable': 34025,
#  'figuring will': 32134,
#  'using twitter': 106276,
#  'result great': 82543,
#  'muffins breakfast': 66458,
#  'cant change deserved': 15551,
#  'please cornwall boring': 76489,
#  'minutes especially': 63974,
#  'anymore stupid work': 5751,
#  'coaching kinda': 18259,
#  'sleep im almost': 89286,
#  'raised celebrated coles': 80278,
#  'gone numerous': 39327,
#  'cash rules everything': 16051,
#  'tags boarding': 95925,
#  'deep laughter': 23720,
#  'kind sick': 53040,
#  'hehe laters': 44557,
#  'attack today tonight': 7232,
#  'gives reason safety': 37671,
#  'course baby': 20781,
#  'school today tomorrow': 85334,
#  'tomorrow lost': 101500,
#  'sooo tempted': 91028,
#  'gov au': 41068,
#  'bloom': 12033,
#  'veiws sites put': 106580,
#  'productive tweet away': 78331,
#  'cheque didnt': 17163,
#  'keeps awake': 52626,
#  'hope stopin till': 46496,
#  'favourite': 31225,
#  'im worried': 48773,
#  'still havent seen': 93140,
#  'given ride shit': 37661,
#  'arielle worth': 6505,
#  'honey lemon': 46147,
#  'got sadly': 40807,
#  'wide enough': 110830,
#  'cooking pan': 20234,
#  'counting get': 20700,
#  'inc cars toy': 49000,
#  'meet mall': 62790,
#  'im soo bored': 48675,
#  'fid distro': 32056,
#  'goodness richard': 40198,
#  'fibro behaving': 32048,
#  'wheel damage car': 110583,
#  'anffb': 5237,
#  'true best one': 102995,
#  'will evaporating': 111005,
#  'home boring suckassy': 45816,
#  'everyone fabulous': 29414,
#  'footpath': 33862,
#  'quot made': 79672,
#  'yay sunny hopefully': 114674,
#  'season started without': 85659,
#  'youtube lonely emiliiee': 115848,
#  'outta water minute': 73442,
#  'friends sure already': 34949,
#  'scared just vid': 85059,
#  '32 one': 1189,
#  'yes got ripped': 115284,
#  'night time': 69289,
#  'alone twitter': 3968,
#  'oooh love way': 72832,
#  'playing basketball today': 76379,
#  'chess': 17186,
#  'subsiding': 94421,
#  'feet macbook just': 31854,
#  'goodmorning twttr': 40188,
#  'puttin cream tattoo': 79015,
#  'big picture boy': 11006,
#  'yay koali happy': 114639,
#  'girls aloud freshly': 37515,
#  'neecee': 67399,
#  'one intentions': 72378,
#  'totally wet': 102153,
#  'hear job': 44244,
#  'mobile iphone': 64667,
#  'site seems': 88863,
#  'arrrggghhh': 6678,
#  'wonderfully magical': 112291,
#  'japannaly hhhahaha': 50400,
#  'reusable': 82647,
#  'tell like': 96962,
#  'working business': 113188,
#  'cant sleep missing': 15627,
#  'man work hard': 61537,
#  'feet haha': 31847,
#  'rn': 83171,
#  'upcoming meeting masterplan': 105489,
#  'twitter yay nice': 104452,
#  'need sleep': 67666,
#  'website later': 109478,
#  'overs now used': 73511,
#  'next lines': 68687,
#  'non stick thats': 69603,
#  'help info': 44794,
#  'ddd world': 23417,
#  'www thegamepayattention com': 114249,
#  'help phone': 44820,
#  'ripped switcheasy colors': 83115,
#  'eye brows': 30283,
#  'wtf snowing': 114109,
#  'getting worse fillings': 37286,
#  'awesome hope like': 7824,
#  'abundant moment using': 2337,
#  'im sad weirdly': 48655,
#  'cs turned': 21522,
#  'yaay wait': 114496,
#  'lined': 56867,
#  'done going short': 25515,
#  'hows life': 47265,
#  'onions pizzas 12': 72703,
#  'played another hand': 76344,
#  'charm mvps': 16832,
#  'capacity fast yesterday': 15709,
#  'office hi twitter': 71064,
#  'dog bed': 25285,
#  'mc bored': 62452,
#  'playcode victor': 76340,
#  'sun come': 94828,
#  'bugs': 13966,
#  'know just wanted': 53501,
#  'going sleep 1am': 39107,
#  'just new': 51902,
#  'agreed': 3261,
#  'want read books': 108211,
#  'ichalinaaa': 48026,
#  'condolences natasha richardson': 19762,
#  'change world can': 16648,
#  'quot µà µà': 80035,
#  'officially change name': 71131,
#  'legend drop dead': 55430,
#  'long re': 58273,
#  'joke': 50968,
#  'know can stop': 53362,
#  'twitter client': 104226,
#  'courtney bible study': 20854,
#  'premier just': 77707,
#  'though dont want': 98997,
#  '13720 html ref_story_id': 415,
#  'indeed hope': 49096,
#  'getting sad hot': 37237,
#  'shit indonesian': 87414,
#  'daddy eyes': 22074,
#  'damn grind inspirational': 22215,
#  'chem wish': 17147,
#  'ráº vui nice': 83979,
#  ...}

# %%
# View a word frequency across the entire corpus
word_vectorizer.vocabulary_.get('pancakes')
# Out:
# 73937

# %%
word_vectorizer.vocabulary_.get('feel sad')
# Out:
# 31584

# %%
# What's the problem with using plain word counts?
# Let's say we have a tweet with unknown sentiment,
# and we want to classify it. If we just use overall
# word frequency, our model is going to weight words
# that are common OVERALL as being more important. But
# what if a word is important within the context of a 
# certain document? Or what if a word appears a lot in
# document A (high document frequency) but doesn't
# appear a lot overall (low term frequency)? We might
# end up misclassifying documents that are very similar
# to document A. To address this, we want to weight a
# word by how important it is to an individual document,
# and offset by how important it is overall. So words
# that are very frequent across the entire corpus have
# lower importance, which makes sense since they're less
# informative. 

# TF(t) = term frequency = How frequently does term occur in document?
#       = (number of times term t appears in a tweet) / (total number of terms in the tweet)
# IDF(t) = inverse document frequency = how important is the term overall?
#        = log(total number of tweets / number of tweets with term t in it).
# TF-IDF(t) = TF(t) * IDF(t)

# We use the word term instead of word because we might have n-grams.

## TODO: in lecture, talk about how this is used in search engines

# %%
from sklearn.feature_extraction.text import TfidfTransformer

tfidf_transformer = TfidfTransformer(use_idf=True).fit(word_doc_matrix)
word_doc_tfidf_matrix = tfidf_transformer.fit_transform(word_doc_matrix)

# %%
# This is our set of features
# We will use these for training
word_doc_tfidf_matrix
# Out:
# <9999x116252 sparse matrix of type '<class 'numpy.float64'>'
# 	with 181840 stored elements in Compressed Sparse Row format>

# %%
tfidf_transformer.idf_
# Out:
# array([ 7.90775528,  9.51719319,  9.51719319, ...,  9.51719319,
#         9.51719319,  9.51719319])

# %%
# DONE WITH FEATURE EXTRACTION!

# TODO: What did we get out of this? A set of features
